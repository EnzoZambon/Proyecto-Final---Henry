# %%
import pandas as pd
import numpy as np

# %%
team = 'C:/Users/Enzo/OneDrive/Escritorio/Henry PF/csv/team.csv'
df_team = pd.read_csv(team, low_memory=True)

# %%
df = df_team

# %%
df.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Atlanta        1949.0
# 1  Massachusetts        1946.0
# 2           Ohio        1970.0
# 3      Louisiana        2002.0
# 4       Illinois        1966.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            30 non-null     int64
#  1   full_name     30 non-null     object
#  2   abbreviation  30 non-null     object
#  3   nickname      30 non-null     object
#  4   city          30 non-null     object
#  5   state         30 non-null     object
#  6   year_founded  30 non-null     float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.8+ KB

# %%
df = df.drop(columns=['nickname', 'year_founded'])

print(df.columns)
# Out:
# Index(['id', 'full_name', 'abbreviation', 'city', 'state'], dtype='object')

# %%
df
# Out:
#             id               full_name abbreviation           city  \
# 0   1610612737           Atlanta Hawks          ATL        Atlanta
# 1   1610612738          Boston Celtics          BOS         Boston
# 2   1610612739     Cleveland Cavaliers          CLE      Cleveland
# 3   1610612740    New Orleans Pelicans          NOP    New Orleans
# 4   1610612741           Chicago Bulls          CHI        Chicago
# 5   1610612742        Dallas Mavericks          DAL         Dallas
# 6   1610612743          Denver Nuggets          DEN         Denver
# 7   1610612744   Golden State Warriors          GSW   Golden State
# 8   1610612745         Houston Rockets          HOU        Houston
# 9   1610612746    Los Angeles Clippers          LAC    Los Angeles
# 10  1610612747      Los Angeles Lakers          LAL    Los Angeles
# 11  1610612748              Miami Heat          MIA          Miami
# 12  1610612749         Milwaukee Bucks          MIL      Milwaukee
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            30 non-null     int64
#  1   full_name     30 non-null     object
#  2   abbreviation  30 non-null     object
#  3   city          30 non-null     object
#  4   state         30 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.3+ KB

# %%
ruta_guardado = "team_listo.csv" 
df.to_csv(ruta_guardado, index=False)
